# %% [markdown]
# #EECS 504 PS2: Signal Processing
#
# Please provide the following information
# (e.g. Andrew Owens, ahowens):
#
# [Aohan] [Mei], [rogermei]
#
# [Collaborated with Zheyu Wen]

# %% [markdown]
# # Starting
#
# Run the following code to import the modules you'll need. After your finish the assignment, remember to run all cells and save the note book to your local machine as a .ipynb file for Canvas submission.

# %%
import numpy as np, matplotlib as mpl, matplotlib.pyplot as plt, urllib, os
import scipy.ndimage # For image filtering
from scipy import signal
from scipy import fft
import imageio # For loading images
import cv2

# cv2.imshow does not work in Colab, we use cv2_imshow instead
from google.colab.patches import cv2_imshow

# %% [markdown]
# # Problem 2.1 2D DFT and convolution theorem
#
# 2.1 (c)
#
# In this problem, we compare the output of a Gaussian filter through i) direct convolution in the spatial domain and ii) multiplication in the frequency domain.

# %%
img_url = 'https://mapproxy.studentlife.umich.edu/images/electrical-engineering-and-computer-science-bld/XP2S3935.jpg'
with open('eecs.jpg', 'wb') as out:
  out.write(urllib.request.urlopen(img_url).read())

img = cv2.imread('eecs.jpg')
img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
img = cv2.resize(img, None, fx=0.25, fy=0.25)
plt.figure()
plt.imshow(img)
plt.title('Original image')
plt.show()

# make a 2-D kernel Gaussian kernel
t = np.linspace(-10, 10, 30)
bump = np.exp(-0.1*t**2)
bump /= np.trapz(bump) # normalize the integral to 1
kernel = bump[:, np.newaxis] * bump[np.newaxis, :]
plt.imshow(kernel)
plt.title('Gaussian kernel')
plt.show()

# convolution in spatial domain
# ===== your code here! =====
img1 = scipy.signal.convolve2d(img,kernel)
# ===== end of code =====
plt.figure()
plt.title('Direct convolution')
plt.imshow(img1)
plt.show()

# multiplication in frequency domain
# shape variable needs to be inputted to the fft2 function
shape = (img.shape[0]+kernel.shape[0]-1, img.shape[1]+kernel.shape[1]-1)
# ===== your code here! =====
img_fft = scipy.fft.fft2(img,shape)
kernel_fft = scipy.fft.fft2(kernel,shape)
img2_fft = img_fft * kernel_fft
img2 = np.abs(scipy.fft.ifft2(img2_fft,shape))
# ===== end of code =====

plt.figure()
plt.title('Multiplication in frequency domain')
plt.imshow(img2)
plt.show()

# %% [markdown]
# # Problem 2.2 Image blending
#
# (a) In this problem, we construct a Laplacian pyramids with 4 levels. We use the Laplacian pyramid to reconstruct the orignal image.

# %%
img_url = 'https://docs.opencv.org/master/roi.jpg'
with open('messi.jpg', 'wb') as out:
  out.write(urllib.request.urlopen(img_url).read())

img = cv2.imread('messi.jpg')
img = cv2.resize(img, (400,200))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F45FEA717F0>

# %%
num_levels = 4 # including the original img

def pyr_up(p, kernel_size=(5,5)):
  '''
  Upsample the pyramid image to get the upper level. 

  Input:
    p: M x N x C array

  Return: 
    out: 2M x 2N x C array
  '''
  # ===== your code here! =====
  
  # Decide the image size
  M = np.shape(p)[0]
  N = np.shape(p)[1]
  H = np.shape(p)[2]
  out = np.zeros(shape=(2*M,2*N,H))
  
  # make a 2-D kernel Gaussian kernel
  t = np.linspace(-10, 10, num = 5)
  bump = np.exp(-0.1*t**2)
  bump /= np.trapz(bump) # normalize the integral to 1
  g_kernel = bump[:, np.newaxis] * bump[np.newaxis, :]

  # Slicing image:
  for j in range(0,H):
    p_slice = p[:,:,j]
    (shape1,shape2) = np.shape(p_slice)
    a = np.linspace(1,shape1,shape1)
    a = a.astype('int')
    b = np.linspace(1,shape2,shape2)
    b = b.astype('int')
    # Upsampling image 
    upsample_ = np.insert(p_slice, tuple(a), 0, axis = 0)
    upsample = np.insert(upsample_, tuple(b), 0, axis = 1)
    # Generate output
    out[:,:,j] = 4 * cv2.GaussianBlur(upsample, kernel_size, sigmaX = 5,sigmaY = 5)

  # ===== end of code =====

  return out

def pyr_down(p, kernel_size=(5,5)):

    '''
    Downsample the pyramid image to get the lower level. 

    Input:
      p: M x N * C array

    Return: 
      out: M/2 x N/2 * C array
    '''
    # ===== your code here! =====

    # Decide the image size
    M = np.shape(p)[0]
    N = np.shape(p)[1]
    H = np.shape(p)[2]

    # Generate output zero matrix 
    out = np.zeros(shape=(int(M/2),int(N/2),H))
    # make a 2-D kernel Gaussian kernel
    t = np.linspace(-10, 10, num = 5)
    bump = np.exp(-0.1*t**2)
    bump /= np.trapz(bump) # normalize the integral to 1
    g_kernel = bump[:, np.newaxis] * bump[np.newaxis, :]
    
    for k in range(0,3):
      p_slice = p[:,:,k]

      # Convolve with original image
      temp_conv = scipy.signal.convolve2d(p_slice, g_kernel)

      # Generate the down-sampling output
      for i in range(0,int(M/2)):
          for j in range(0,int(N/2)):
            out[i,j,k] = temp_conv[2*i][2*j]

    # ===== end of code =====

    return out

def gaussian_pyramid(img, num_levels):

  '''
  Input
    img: N x M x C array

  Return
    gp: list, the generated levels of the Gaussian pyramids
  '''
  gp = []
  gp.append(img)
  img_temp = img
  # ===== your code here! =====
  
  for i in range(0,num_levels-1):
    img_temp = pyr_down(img_temp)
    gp.append(img_temp)

  # ===== end of code =====

  return gp

def laplacian_pyramid(gp, num_levels):
  '''
  Input
    gp: list, Gaussian pyramids

  Return
    lp: list, Laplacian pyramids
  '''
  # ===== your code here! =====

  lp = []
  if num_levels == 1:
    lp.append(gp[0])
    return lp
  for i in range(num_levels-1):
    upsample = pyr_up(gp[i+1])
    if np.shape(gp[i]) != np.shape(upsample):
      pyrup_gpexpand = np.zeros(np.shape(gp[i]))
      pyrup_gpexpand[0:np.shape(gp[i])[0]-1,:,:] = upsample
      residual = gp[i] - pyrup_gpexpand(gp[i+1])
    else:
      residual = gp[i] - upsample
    lp.append(residual)
    if i == (num_levels - 2):
      lp.append(gp[i+1])
  # ===== end of code =====

  return lp

def reconstruct_img(lp):
  '''
  reconstruct images using the laplacian pyramid.

  Input:
    lp: list, Laplacian pyramids

  Return:
    recon_img: array, reconstructed image
  '''
  # ===== your code here! =====
  if len(lp) == 1:
    return lp[0]
  length = len(lp)
  recon_img = pyr_up(lp[length-1])
  for i in range(1, len(lp)):
    recon_img = lp[length - i - 1] + recon_img
    if i != (len(lp)-1):
      recon_img = pyr_up(recon_img)
  # ===== end of code =====

  return recon_img

# %%
gp = gaussian_pyramid(img, num_levels)
lp = laplacian_pyramid(gp, num_levels)
recon_img = reconstruct_img(lp)

print('Laplacian pyramid')
for L in lp:
  cv2_imshow(L)

print('original image')
cv2_imshow(img)

print('reconstructed image')
cv2_imshow(recon_img)
# Out:
# 4
# Laplacian pyramid
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F45FEADA048>
# <PIL.Image.Image image mode=RGB size=200x100 at 0x7F45FEADA048>
# <PIL.Image.Image image mode=RGB size=100x50 at 0x7F45FEADA5C0>
# <PIL.Image.Image image mode=RGB size=50x25 at 0x7F45FEADA5C0>
# original image
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F45FEBAB160>
# reconstructed image
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F45FEBAB438>

# %% [markdown]
# # 2.2 (b) Blend two images

# %%
base_url = 'https://inst.eecs.berkeley.edu/~cs194-26/fa17/upload/files/proj3/cs194-26-acr/img/multires1/'
for name in ['orange.jpg', 'apple.jpg']:
  with open(name, 'wb') as out:
    url = os.path.join(base_url, name)
    out.write(urllib.request.urlopen(url).read())

# %%
img1 = cv2.imread('apple.jpg')
img2 = cv2.imread('orange.jpg')
img1 = cv2.resize(img1, None, fx=0.5, fy=0.5)
img2 = cv2.resize(img2, None, fx=0.5, fy=0.5)

mask = np.zeros_like(img1)
mask[:mask.shape[1]//2, :, :] = 1

# %%
def pyr_blend(img1, img2, mask, num_levels=6):
  '''
  This function produces the Laplacian pyramid blend of two images.

  Input
    type img1: N x M x C uint8 array
    type img2: N x M x C uint8 array
    type mask: N x M x C array, all elements are either 0s or 1s
    type num_level: int, height of the pyramids
  
  Return
    img_blend: N x M x C uint8 array
  '''

  # build Gaussian pyramids for img1, img2, and mask
  gp1, gp2, gpm = gaussian_pyramid(img1, num_levels), gaussian_pyramid(img2, num_levels), gaussian_pyramid(mask, num_levels)

  # build Laplaican pyramids for img1 and img2 
  lp1, lp2, lpm = laplacian_pyramid(gp1, num_levels), laplacian_pyramid(gp2, num_levels), laplacian_pyramid(gpm, num_levels)
 
  # blend two images starting from the level with lowest resolution
  # ===== your code here! =====
  lk_blend = []
  for i in range(len(gpm)):
    a = lp1[i] * gpm[i]
    b = lp2[i] * (1 - gpm[i])
    lk_blend.append((a+b))
  
  img_blend = reconstruct_img(lk_blend)
  # ===== end of code =====

  return img_blend

# %%
cv2_imshow(img1)
cv2_imshow(img2)
cv2_imshow(mask * 255)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA8AE80>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA8AEF0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA8AB00>

# %%
# Laplacian pyramid blend with different levels
for n_l in range(1, 7):
  img_blend = pyr_blend(img1.astype(float), img2.astype(float), mask.astype(float), num_levels=n_l)
  print('Number of levels = {}'.format(n_l))
  cv2_imshow(img_blend)
# Out:
# Number of levels = 1
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA2A1D0>
# Number of levels = 2
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA8D470>
# Number of levels = 3
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA2A080>
# Number of levels = 4
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA2A550>
# Number of levels = 5
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA2A550>
# Number of levels = 6
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F45FEA8DBE0>
